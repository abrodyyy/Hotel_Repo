# %%
# Importing libraries
import pandas as pd

# %%
# Reading in dataset
file_path = r"C:\Users\aleah\Class\Final_Project\hotel_bookings.csv"
hotels_df = pd.read_csv(file_path)
hotels_df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
# Exploring the columns 
hotels_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Splitting dataset into 2

# Resort hotel
resort_hotel_df = hotels_df.loc[hotels_df['hotel'] == 'Resort Hotel']
resort_hotel_df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  40060.000000  40060.000000       40060.000000
# mean       0.277634     92.675686        2016.121443
# std        0.447837     97.285315           0.722347
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     10.000000        2016.000000
# 50%        0.000000     57.000000        2016.000000
# 75%        1.000000    155.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              40060.000000               40060.000000
# mean                  27.140864                  15.821243
# std                   14.005441                   8.883708
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  24.000000
# ...

# %%
# City hotel
city_hotel_df = hotels_df.loc[hotels_df['hotel'] == 'City Hotel']
city_hotel_df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  79330.000000  79330.000000       79330.000000
# mean       0.417270    109.735724        2016.174285
# std        0.493111    110.948526           0.699181
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     23.000000        2016.000000
# 50%        0.000000     74.000000        2016.000000
# 75%        1.000000    163.000000        2017.000000
# max        1.000000    629.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              79330.000000               79330.000000
# mean                  27.177449                  15.786625
# std                   13.398523                   8.728451
# min                    1.000000                   1.000000
# 25%                   17.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
# Number of cancellations at the Resort Hotel by month
resort_cancellations_month = resort_hotel_df.groupby(['arrival_date_month']).sum()['is_canceled']
resort_cancellations_month.sort_values(ascending=False)
# Out:
# arrival_date_month
# August       1637
# July         1436
# April        1059
# May          1024
# June         1007
# September    1006
# October       978
# February      795
# March         763
# December      631
# November      461
# January       325
# Name: is_canceled, dtype: int64

# %%
# Number of cancellations at the City Hotel by month
city_cancellations_month = city_hotel_df.groupby(['arrival_date_month']).sum()['is_canceled']
city_cancellations_month.sort_values(ascending=False)
# Out:
# arrival_date_month
# May          3653
# August       3602
# June         3528
# April        3465
# July         3306
# October      3268
# September    3110
# March        2386
# February     1901
# December     1740
# November     1661
# January      1482
# Name: is_canceled, dtype: int64

# %%
# Plotting cancellations 
hotels_df.plot(x="arrival_date_month", y=["resort_cancellations_month"], kind="bar")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22716\505530933.py in <module>
#       1 # Plotting cancellations
# ----> 2 hotels_df.plot(x="arrival_date_month", y=["resort_cancellations_month"], kind="bar")
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     956
#     957                 # don't overwrite
# --> 958                 data = data[y].copy()
#     959
#     960                 if isinstance(data, ABCSeries):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ...

# %%
import matplotlib.pyplot as plt

resort_cancellations_month.sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='arrival_date_month'>

# %%
city_cancellations_month.sort_values(ascending=False).plot(kind='pie', autopct='%.1f%%')
# Out:
# <AxesSubplot:ylabel='is_canceled'>

# %%
# Mean ADR (average daily rate) of cancellations vs non-cancellations
# (SHOULD I BE MULTIPLYING THE ADR BY TOTAL NIGHTS STAYED/BOOKED?)
adr_per_canellations = hotels_df.loc[hotels_df['is_canceled'] == 1, 'adr'].mean()
adr_per_noncancellations = hotels_df.loc[hotels_df['is_canceled'] == 0, 'adr'].mean()

print(f"The mean average daily rate for canceled reservations was: {adr_per_canellations}")
print(f"The mean average daily rate for non-canceled reservations was: {adr_per_noncancellations}")
# Out:
# The mean average daily rate for canceled reservations was: 104.96433316750777
# The mean average daily rate for non-canceled reservations was: 99.9876929728839
